# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanwhistle/Transformer_Reimplementation/blob/main/run_using_repo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
_mnt_path = '/content/drive'
_current_path = f'{_mnt_path}/MyDrive/Transformer_Reimple'
drive.mount(_mnt_path)

# %cd '{_current_path}'
# !git clone https://github.com/dongheechoi/transformer_impl
# %cd '{_current_path}/transformer_impl'

# !git pull
# !pip install -r requirements.txt
# %run main.py --output_dir=../outputs/  --cache_dir=../data/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Transformer_Reimple
# Cloning into 'transformer_impl'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 25 (delta 10), reused 6 (delta 1), pack-reused 0
# Unpacking objects: 100% (25/25), done.
# /content/drive/MyDrive/Transformer_Reimple/transformer_impl
# Already up to date.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 68.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 13.3 MB/s eta 0:00:00
# ...

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 4508785
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 3003
#     })
# })

# %%
torch
# Out:
# <module 'torch' from '/usr/local/lib/python3.8/dist-packages/torch/__init__.py'>

# %%
# setting device on GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cpu
